# %%
import pandas as pd

# %%
df=pd.read_csv("India Agriculture Crop Production.csv")
df=df.dropna()
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-181c4a08da63> in <cell line: 1>()
# ----> 1 df=pd.read_csv("India Agriculture Crop Production.csv")
#       2 df=df.dropna()
#       3 df
#
# NameError: name 'pd' is not defined

# %%
df = df.groupby(['State', 'Crop'])['Yield'].mean().reset_index()
df
# Out:
#                             State          Crop     Yield
# 0     Andaman and Nicobar Islands      Arecanut  1.745437
# 1     Andaman and Nicobar Islands     Arhar/Tur  0.962048
# 2     Andaman and Nicobar Islands        Banana  9.433950
# 3     Andaman and Nicobar Islands  Black pepper  0.258716
# 4     Andaman and Nicobar Islands     Cashewnut  0.543941
# ...                           ...           ...       ...
# 1093                  West Bengal     Sunflower  1.167517
# 1094                  West Bengal       Tobacco  0.917757
# 1095                  West Bengal      Turmeric  1.784816
# 1096                  West Bengal          Urad  0.660014
# 1097                  West Bengal         Wheat  2.303346
#
# [1098 rows x 3 columns]

# %%
df1=pd.read_csv("statwise seaparated csv files after dropping nulls/Andaman_and_Nicobar_Islands_cropsallseason.csv")
df1=df1.groupby(["Crop"])["Yield"].mean().reset_index()
df1
# Out:
#                    Crop        Yield
# 0              Arecanut     1.745437
# 1             Arhar/Tur     0.962048
# 2                Banana     9.433950
# 3          Black pepper     0.258716
# 4             Cashewnut     0.543941
# 5               Coconut  4848.274533
# 6         Cowpea(Lobia)     4.634418
# 7            Dry Ginger     8.052699
# 8          Dry chillies     3.091185
# 9                Ginger     6.208805
# 10            Groundnut     0.844143
# 11                Maize     2.515501
# 12    Moong(Green Gram)     0.602703
# 13       Oilseeds total     0.628912
# 14  Other Kharif pulses     0.536684
# 15    Rapeseed &Mustard     0.874697
# 16                 Rice     2.358529
# 17            Safflower     0.500000
# 18              Sesamum     0.505648
# 19            Sugarcane    13.969172
# 20            Sunflower     1.056303
# 21         Sweet potato    13.902747
# 22              Tapioca    13.298187
# 23             Turmeric     6.056033
# ...

# %%
df2=pd.read_csv("statwise seaparated csv files after dropping nulls/Andhra_Pradesh_cropsallseason.csv")
df2=df2.groupby(["Crop"])["Yield"].mean().reset_index()
df2
# Out:
#                    Crop         Yield
# 0              Arecanut      2.173744
# 1             Arhar/Tur      0.484479
# 2                 Bajra      1.173979
# 3                Banana     36.568109
# 4          Black pepper      0.937500
# 5             Cashewnut      0.433212
# 6           Castor seed      0.491866
# 7               Coconut  11483.621985
# 8             Coriander      0.524754
# 9          Cotton(lint)      2.034766
# 10        Cowpea(Lobia)      0.601662
# 11         Dry chillies      2.950180
# 12               Garlic      2.168091
# 13               Ginger      4.320330
# 14                 Gram      1.271706
# 15            Groundnut      1.571550
# 16            Guar seed      1.904762
# 17           Horse-gram      0.431838
# 18                Jowar      1.351240
# 19              Linseed      0.273648
# 20                Maize      4.534665
# 21               Masoor      0.363275
# 22                Mesta      8.279828
# 23    Moong(Green Gram)      0.494952
# ...

# %%
df3=pd.read_csv("statwise seaparated csv files after dropping nulls/Arunachal_Pradesh_cropsallseason.csv")
df3=df3.groupby(["Crop"])["Yield"].mean().reset_index()
df3
# Out:
#                      Crop      Yield
# 0               Arhar/Tur   0.820206
# 1            Dry chillies   2.228165
# 2                  Ginger   6.222175
# 3               Groundnut   1.105889
# 4                   Maize   1.548824
# 5                  Masoor   0.741371
# 6       Moong(Green Gram)   1.092038
# 7          Oilseeds total   1.067637
# 8     Other Kharif pulses   0.927496
# 9       Other Rabi pulses   0.727275
# 10  Peas & beans (Pulses)   1.322509
# 11                 Potato   7.058188
# 12      Rapeseed &Mustard   1.167139
# 13                   Rice   1.349769
# 14                Sesamum   0.800252
# 15          Small millets   0.977250
# 16               Soyabean   1.593565
# 17              Sugarcane  19.319244
# 18              Sunflower   0.697327
# 19               Turmeric   4.417472
# 20                   Urad   0.972007
# 21                  Wheat   1.696817
# 22         other oilseeds   1.121690

# %%
df4=pd.read_csv("statwise seaparated csv files after dropping nulls/Assam_cropsallseason.csv")
df4=df4.groupby(["Crop"])["Yield"].mean().reset_index()
df4
# Out:
#                      Crop        Yield
# 0                Arecanut     0.899445
# 1               Arhar/Tur     0.769853
# 2                  Banana    15.050940
# 3            Black pepper     1.803838
# 4             Castor seed     0.498205
# 5                 Coconut  7222.916381
# 6            Cotton(lint)     0.502276
# 7            Dry chillies     0.704829
# 8                  Ginger     7.903286
# 9                    Gram     0.544758
# 10                   Jute    10.048379
# 11                Linseed     0.535622
# 12                  Maize     1.403536
# 13                 Masoor     0.591031
# 14                  Mesta     5.156332
# 15      Moong(Green Gram)     0.535800
# 16             Niger seed     0.545802
# 17                  Onion     3.668782
# 18      Other Rabi pulses     0.573578
# 19  Peas & beans (Pulses)     0.729847
# 20                 Potato     7.109207
# 21      Rapeseed &Mustard     0.544581
# 22                   Rice     1.681778
# ...

# %%
df5=pd.read_csv("statwise seaparated csv files after dropping nulls/Bihar_cropsallseason.csv")
df5=df5.groupby(["Crop"])["Yield"].mean().reset_index()
df5
# Out:
#                      Crop      Yield
# 0               Arhar/Tur   1.451509
# 1                   Bajra   0.901566
# 2                  Banana  18.304182
# 3                  Barley   1.240529
# 4             Castor seed   0.941166
# 5               Coriander   0.692186
# 6            Cotton(lint)   2.023256
# 7            Dry chillies   0.936220
# 8                  Garlic   1.457229
# 9                  Ginger   1.523142
# 10                   Gram   0.996038
# 11              Groundnut   0.872035
# 12             Horse-gram   0.870018
# 13                  Jowar   1.068770
# 14                   Jute  10.028213
# 15                Khesari   0.863678
# 16                Linseed   0.787620
# 17                  Maize   2.925444
# 18                 Masoor   0.841365
# 19                  Mesta   7.663318
# 20      Moong(Green Gram)   0.648356
# 21             Niger seed   0.610655
# 22                  Onion   9.875076
# 23    Other Kharif pulses   0.698378
# ...

# %%
df6=pd.read_csv("statwise seaparated csv files after dropping nulls/Chandigarh_cropsallseason.csv")
df6=df6.groupby(["Crop"])["Yield"].mean().reset_index()
df6
# Out:
#                  Crop      Yield
# 0           Arhar/Tur   1.000000
# 1                Gram   1.000000
# 2               Maize   2.273806
# 3              Masoor   1.437500
# 4   Moong(Green Gram)   1.000000
# 5               Onion  20.259259
# 6              Potato  19.702469
# 7   Rapeseed &Mustard   1.387143
# 8                Rice   4.934091
# 9           Sunflower   2.800000
# 10               Urad   0.886667
# 11              Wheat   4.562376

# %%
df7=pd.read_csv("statwise seaparated csv files after dropping nulls/Chattisgarh_cropsallseason.csv")
df7=df7.groupby(["Crop"])["Yield"].mean().reset_index()
df7
# Out:
#                      Crop      Yield
# 0               Arhar/Tur   0.501582
# 1                   Bajra   0.546694
# 2                  Banana  32.789528
# 3                  Barley   0.848195
# 4             Castor seed   0.388131
# 5               Coriander   0.294792
# 6            Cotton(lint)   1.571023
# 7            Dry chillies   0.614061
# 8                  Garlic   2.936497
# 9                  Ginger   1.201963
# 10                   Gram   0.856329
# 11              Groundnut   1.339269
# 12              Guar seed   0.807692
# 13             Horse-gram   0.338704
# 14                  Jowar   0.988924
# 15                Khesari   0.611915
# 16                Linseed   0.323376
# 17                  Maize   1.731495
# 18                 Masoor   0.327281
# 19                  Mesta   2.057777
# 20      Moong(Green Gram)   0.298612
# 21             Niger seed   0.470616
# 22                  Onion   5.999250
# 23    Other Kharif pulses   0.293089
# ...

# %%
df8=pd.read_csv("statwise seaparated csv files after dropping nulls/dadra_and_nagar_haveli_cropsallseason.csv")
df8=df8.groupby(["Crop"])["Yield"].mean().reset_index()
df8
# Out:
#     Crop     Yield
# 0  Bajra  1.503804
# 1   Rice  1.202466

# %%
df9=pd.read_csv("statwise seaparated csv files after dropping nulls/delhi_cropsallseason.csv")
df9=df9.groupby(["Crop"])["Yield"].mean().reset_index()
df9
# Out:
#                    Crop      Yield
# 0             Arhar/Tur   1.460907
# 1                 Bajra   1.979121
# 2                Barley   2.249569
# 3          Cotton(lint)   1.000000
# 4                  Gram   1.734890
# 5                 Jowar   0.877253
# 6                 Maize   8.030629
# 7   Other Kharif pulses   1.402873
# 8                Potato  65.809701
# 9     Rapeseed &Mustard   2.500000
# 10                 Rice   2.675311
# 11            Sugarcane  69.291667
# 12                Wheat   4.190853

# %%
df10=pd.read_csv("statwise seaparated csv files after dropping nulls/goa_cropsallseason.csv")
df10=df10.groupby(["Crop"])["Yield"].mean().reset_index()
df10
# Out:
#                    Crop        Yield
# 0              Arecanut     1.683212
# 1                Banana    10.288917
# 2          Black pepper     0.299754
# 3             Cashewnut     0.425997
# 4               Coconut  5070.797691
# 5             Groundnut     2.015658
# 6                 Maize     4.000000
# 7   Other Kharif pulses     0.639890
# 8     Other Rabi pulses     0.952256
# 9                  Ragi     0.969875
# 10                 Rice     2.685495
# 11            Sugarcane    51.048562
# 12         Sweet potato     2.604669
# 13       other oilseeds     2.281533

# %%
df11=pd.read_csv("statwise seaparated csv files after dropping nulls/gujrat_cropsallseason.csv")
df11=df11.groupby(["Crop"])["Yield"].mean().reset_index()
df11
# Out:
#                    Crop      Yield
# 0             Arhar/Tur   0.996567
# 1                 Bajra   1.858633
# 2                Banana  65.909002
# 3           Castor seed   1.964469
# 4          Cotton(lint)   2.910191
# 5          Dry chillies   0.976886
# 6                Garlic   5.802570
# 7                  Gram   1.001397
# 8             Groundnut   1.707704
# 9             Guar seed   0.780797
# 10                Jowar   1.105287
# 11                Maize   1.747241
# 12    Moong(Green Gram)   0.569441
# 13                 Moth   0.461420
# 14       Oilseeds total   1.342321
# 15                Onion  27.207571
# 16        Other Cereals   0.879942
# 17  Other Kharif pulses   0.530689
# 18    Other Rabi pulses   0.729761
# 19               Potato  23.785239
# 20                 Ragi   0.922681
# 21    Rapeseed &Mustard   1.477983
# 22                 Rice   2.191599
# 23              Sesamum   1.398970
# 24        Small millets   0.771824
# 25             Soyabean   1.006393
# ...

# %%
df12=pd.read_csv("statwise seaparated csv files after dropping nulls/haryana_cropsallseason.csv")
df12=df11.groupby(["Crop"])["Yield"].mean().reset_index()
df12
# Out:
#                    Crop      Yield
# 0             Arhar/Tur   0.996567
# 1                 Bajra   1.858633
# 2                Banana  65.909002
# 3           Castor seed   1.964469
# 4          Cotton(lint)   2.910191
# 5          Dry chillies   0.976886
# 6                Garlic   5.802570
# 7                  Gram   1.001397
# 8             Groundnut   1.707704
# 9             Guar seed   0.780797
# 10                Jowar   1.105287
# 11                Maize   1.747241
# 12    Moong(Green Gram)   0.569441
# 13                 Moth   0.461420
# 14       Oilseeds total   1.342321
# 15                Onion  27.207571
# 16        Other Cereals   0.879942
# 17  Other Kharif pulses   0.530689
# 18    Other Rabi pulses   0.729761
# 19               Potato  23.785239
# 20                 Ragi   0.922681
# 21    Rapeseed &Mustard   1.477983
# 22                 Rice   2.191599
# 23              Sesamum   1.398970
# 24        Small millets   0.771824
# 25             Soyabean   1.006393
# ...

# %%
df13=pd.read_csv("statwise seaparated csv files after dropping nulls/jandk_cropsallseason.csv")
df13=df13.groupby(["Crop"])["Yield"].mean().reset_index()
df13
# Out:
#                      Crop      Yield
# 0               Arhar/Tur   0.550000
# 1                   Bajra   0.578184
# 2                  Barley   0.628368
# 3               Coriander   0.125000
# 4            Cotton(lint)   0.495584
# 5           Cowpea(Lobia)   0.641037
# 6            Dry chillies   0.900125
# 7                  Garlic   0.830369
# 8                  Ginger   1.525339
# 9                    Gram   0.522016
# 10              Groundnut   0.557932
# 11             Horse-gram   0.381399
# 12                  Jowar   0.479096
# 13                Linseed   0.641467
# 14                  Maize   1.505259
# 15                 Masoor   0.627283
# 16      Moong(Green Gram)   0.542674
# 17                   Moth   0.675749
# 18                  Onion   1.839894
# 19          Other Cereals   0.794990
# 20    Other Kharif pulses   0.824132
# 21      Other Rabi pulses   0.711074
# 22  Peas & beans (Pulses)   1.097487
# 23                 Potato  10.098838
# ...

# %%
df14=pd.read_csv("statwise seaparated csv files after dropping nulls/jharkhand_cropsallseason.csv")
df14=df14.groupby(["Crop"])["Yield"].mean().reset_index()
df14
# Out:
#                      Crop      Yield
# 0               Arhar/Tur   2.119824
# 1                   Bajra   0.613667
# 2                  Barley   0.859230
# 3             Castor seed   0.535132
# 4                    Gram   0.940713
# 5               Groundnut   0.942685
# 6              Horse-gram   0.644645
# 7                   Jowar   0.710984
# 8                 Linseed   0.582349
# 9                   Maize   1.536017
# 10                 Masoor   0.804121
# 11      Moong(Green Gram)   0.776460
# 12             Niger seed   0.505360
# 13                  Onion   7.900954
# 14    Other Kharif pulses   0.621317
# 15      Other Rabi pulses   0.703480
# 16  Peas & beans (Pulses)   1.116989
# 17                 Potato   7.446992
# 18                   Ragi   0.853670
# 19      Rapeseed &Mustard   0.840267
# 20                   Rice   1.153745
# 21              Safflower   0.564447
# 22                Sesamum   0.406280
# 23               Soyabean   0.829197
# ...

# %%
df15=pd.read_csv("statwise seaparated csv files after dropping nulls/karnataka_cropsallseason.csv")
df15=df15.groupby(["Crop"])["Yield"].mean().reset_index()
df15
# Out:
#                      Crop        Yield
# 0                Arecanut     6.723126
# 1               Arhar/Tur     0.542558
# 2                   Bajra     0.840888
# 3                  Banana    19.697382
# 4            Black pepper     1.765687
# 5                Cardamom     0.091080
# 6               Cashewnut     0.905204
# 7             Castor seed     0.800376
# 8                 Coconut  6720.231326
# 9               Coriander     0.318403
# 10           Cotton(lint)     1.791095
# 11          Cowpea(Lobia)     0.376853
# 12           Dry chillies     1.888523
# 13                 Garlic     1.980954
# 14                 Ginger    18.336020
# 15                   Gram     0.533637
# 16              Groundnut     0.888460
# 17             Horse-gram     0.482335
# 18                  Jowar     1.239224
# 19                Linseed     0.303418
# 20                  Maize     2.931614
# 21                  Mesta     1.550413
# 22      Moong(Green Gram)     0.249253
# ...

# %%
df16=pd.read_csv("statwise seaparated csv files after dropping nulls/Kerala_cropsallseason.csv")
df16=df16.groupby(["Crop"])["Yield"].mean().reset_index()
df16
# Out:
#                    Crop        Yield
# 0              Arecanut     0.888247
# 1             Arhar/Tur     1.407373
# 2                Banana     8.429225
# 3          Black pepper     0.269037
# 4              Cardamom     0.093853
# 5             Cashewnut     0.461676
# 6               Coconut  6270.147640
# 7          Cotton(lint)     1.510732
# 8          Dry chillies     0.953162
# 9                Garlic    12.860037
# 10               Ginger     3.284950
# 11                 Gram     0.732174
# 12            Groundnut     0.957552
# 13                Jowar     0.653613
# 14                Maize     2.387455
# 15        Other Cereals     0.907178
# 16  Other Kharif pulses     1.105610
# 17    Other Rabi pulses     1.098738
# 18               Potato    12.855685
# 19                 Ragi     0.946038
# 20                 Rice     2.301646
# 21              Sesamum     0.398773
# 22        Small millets     0.751118
# 23             Soyabean     1.332143
# ...

# %%
df17=pd.read_csv("statwise seaparated csv files after dropping nulls/laddakh_cropsallseason.csv")
df17=df17.groupby(["Crop"])["Yield"].mean().reset_index()
df17
# Out:
#             Crop  Yield
# 0  Other Cereals    0.4

# %%
df18=pd.read_csv("statwise seaparated csv files after dropping nulls/madhya_Pradesh_cropsallseason.csv")
df18=df18.groupby(["Crop"])["Yield"].mean().reset_index()
df18
# Out:
#                      Crop      Yield
# 0               Arhar/Tur   0.751148
# 1                   Bajra   1.129464
# 2                  Banana  36.985944
# 3                  Barley   1.770557
# 4               Cashewnut   0.000000
# 5             Castor seed   0.361530
# 6               Coriander   0.755516
# 7            Cotton(lint)   1.015372
# 8           Cowpea(Lobia)   0.294866
# 9            Dry chillies   1.615469
# 10                 Garlic   5.060127
# 11                 Ginger   5.963327
# 12                   Gram   1.009068
# 13              Groundnut   1.159586
# 14             Horse-gram   0.316036
# 15                  Jowar   1.322190
# 16                   Jute   1.533988
# 17                Khesari   0.664477
# 18                Linseed   0.613341
# 19                  Maize   1.731419
# 20                 Masoor   0.610554
# 21                  Mesta   1.089197
# 22      Moong(Green Gram)   0.432650
# 23             Niger seed   0.263982
# ...

# %%
df19=pd.read_csv("statwise seaparated csv files after dropping nulls/manipurcropsallseason.csv")
df19=df19.groupby(["Crop"])["Yield"].mean().reset_index()
df19
# Out:
#                    Crop       Yield
# 0             Arhar/Tur    1.005734
# 1                Banana   14.377778
# 2               Coconut  301.636637
# 3             Coriander    0.800000
# 4         Cowpea(Lobia)    1.200000
# 5                  Gram    0.907329
# 6             Groundnut    1.153274
# 7                 Jowar    1.981685
# 8                 Maize    0.998299
# 9            Niger seed    0.957981
# 10  Other Kharif pulses    0.919962
# 11    Other Rabi pulses    0.910569
# 12                 Ragi    1.304475
# 13    Rapeseed &Mustard    0.860269
# 14                 Rice    2.045561
# 15             Sannhamp    0.621888
# 16              Sesamum    0.760417
# 17        Small millets    0.928248
# 18            Sugarcane   79.781574
# 19            Sunflower    0.600000
# 20                 Urad    0.943074
# 21                Wheat    1.976589

# %%
df20=pd.read_csv("statwise seaparated csv files after dropping nulls/meghalaya_cropsallseason.csv")
df20=df20.groupby(["Crop"])["Yield"].mean().reset_index()
df20
# Out:
#                      Crop      Yield
# 0                Arecanut   1.269223
# 1               Arhar/Tur   0.946553
# 2                  Banana  10.617425
# 3            Black pepper   0.689062
# 4               Cashewnut   1.458000
# 5             Castor seed   0.794690
# 6               Coriander   3.946308
# 7            Cotton(lint)   1.037135
# 8           Cowpea(Lobia)   1.603656
# 9            Dry chillies   0.957894
# 10                 Garlic   1.787915
# 11                 Ginger   7.829413
# 12                   Gram   0.808524
# 13                   Jute   8.183058
# 14                Linseed   0.532396
# 15                  Maize   1.825557
# 16                 Masoor   1.231504
# 17                  Mesta   5.328589
# 18         Oilseeds total   0.717669
# 19                  Onion   8.342368
# 20      Other Rabi pulses   0.780135
# 21  Peas & beans (Pulses)   1.678961
# 22                 Potato   7.473813
# 23      Rapeseed &Mustard   0.746817
# ...

# %%
df21=pd.read_csv("statwise seaparated csv files after dropping nulls/mizoram_cropsallseason.csv")
df21=df21.groupby(["Crop"])["Yield"].mean().reset_index()
df21
# Out:
#                      Crop      Yield
# 0               Arhar/Tur   1.064036
# 1                 Coconut   2.596154
# 2            Cotton(lint)   1.352266
# 3           Cowpea(Lobia)   1.221650
# 4                    Gram   1.045635
# 5               Groundnut   1.119791
# 6                   Maize   1.727191
# 7                  Masoor   0.918472
# 8       Moong(Green Gram)   1.065317
# 9                   Onion   5.604927
# 10    Other Kharif pulses   1.117631
# 11      Other Rabi pulses   1.502957
# 12  Peas & beans (Pulses)   1.080275
# 13                 Potato   4.959071
# 14      Rapeseed &Mustard   0.946687
# 15                   Rice   1.651105
# 16                Sesamum   0.681257
# 17               Soyabean   1.344042
# 18              Sugarcane  15.394691
# 19              Sunflower   0.887074
# 20                Tapioca   7.545401
# 21                Tobacco   0.779231
# 22                   Urad   1.084697
# 23                  Wheat   0.979308
# ...

# %%
df22=pd.read_csv("statwise seaparated csv files after dropping nulls/Nagaland_cropsallseason.csv")
df22=df22.groupby(["Crop"])["Yield"].mean().reset_index()
df22
# Out:
#                      Crop      Yield
# 0               Arhar/Tur   0.910211
# 1                   Bajra   1.010849
# 2                  Barley   1.299831
# 3                Cardamom   0.755639
# 4             Castor seed   0.681551
# 5            Cotton(lint)   1.188935
# 6           Cowpea(Lobia)   1.468897
# 7            Dry chillies   1.262695
# 8                  Ginger   9.011244
# 9                    Gram   0.857366
# 10              Groundnut   1.055032
# 11             Horse-gram   1.037526
# 12                  Jowar   1.051479
# 13                   Jute   2.912421
# 14                Linseed   0.756420
# 15                  Maize   1.824614
# 16                 Masoor   0.852222
# 17                  Mesta   1.232856
# 18      Moong(Green Gram)   0.977586
# 19             Niger seed   0.848956
# 20         Oilseeds total   1.022296
# 21          Other Cereals   1.021830
# 22    Other Kharif pulses   1.066944
# 23      Other Rabi pulses   1.113667
# ...

# %%
df23=pd.read_csv("statwise seaparated csv files after dropping nulls/odisha_cropsallseason.csv")
df23=df23.groupby(["Crop"])["Yield"].mean().reset_index()
df23
# Out:
#                      Crop      Yield
# 0               Arhar/Tur   0.560120
# 1                   Bajra   0.559808
# 2             Castor seed   0.542270
# 3               Coriander   0.489440
# 4            Cotton(lint)   2.014870
# 5           Cowpea(Lobia)   0.738881
# 6            Dry chillies   0.906296
# 7                  Garlic   3.268200
# 8                  Ginger   3.504843
# 9                    Gram   0.554342
# 10              Groundnut   1.124321
# 11             Horse-gram   0.311922
# 12                  Jowar   0.586421
# 13                   Jute   5.534872
# 14                Linseed   0.396111
# 15                  Maize   1.471752
# 16                 Masoor   0.420015
# 17                  Mesta   4.177214
# 18      Moong(Green Gram)   0.299345
# 19             Niger seed   0.307065
# 20                  Onion   8.843445
# 21    Other Kharif pulses   0.478295
# 22      Other Rabi pulses   0.569277
# 23  Peas & beans (Pulses)   0.770806
# ...

# %%
df24=pd.read_csv("statwise seaparated csv files after dropping nulls/puducherry_cropsallseason.csv")
df24=df24.groupby(["Crop"])["Yield"].mean().reset_index()
df24
# Out:
#                    Crop         Yield
# 0              Arecanut      1.437981
# 1                 Bajra      2.346135
# 2                Banana     22.904936
# 3          Black pepper      0.832997
# 4             Cashewnut      0.766730
# 5               Coconut  11309.349693
# 6             Coriander      0.678788
# 7          Cotton(lint)      2.060207
# 8          Dry chillies      4.348219
# 9                Ginger      0.552241
# 10            Groundnut      2.015708
# 11                Jowar      1.912037
# 12    Moong(Green Gram)      0.565109
# 13                Onion      9.063895
# 14        Other Cereals      2.033670
# 15  Other Kharif pulses      1.121647
# 16    Other Rabi pulses      1.054274
# 17  Other Summer Pulses      1.352381
# 18                 Ragi      2.136693
# 19    Rapeseed &Mustard      6.185902
# 20                 Rice      2.909750
# 21              Sesamum      0.732204
# 22        Small millets      1.098016
# 23            Sugarcane    101.029167
# ...

# %%
df25=pd.read_csv("statwise seaparated csv files after dropping nulls/punjab_cropsallseason.csv")
df25=df25.groupby(["Crop"])["Yield"].mean().reset_index()
df25
# Out:
#                      Crop      Yield
# 0               Arhar/Tur   0.956964
# 1                   Bajra   0.939035
# 2                  Barley   3.467100
# 3            Cotton(lint)   3.136012
# 4                    Gram   1.024388
# 5               Groundnut   1.067038
# 6               Guar seed   0.888858
# 7                   Jowar   1.000000
# 8                 Linseed   1.000000
# 9                   Maize   3.295247
# 10                 Masoor   0.702925
# 11      Moong(Green Gram)   0.808435
# 12                   Moth   0.875000
# 13      Other Rabi pulses   1.007071
# 14  Peas & beans (Pulses)   1.159760
# 15      Rapeseed &Mustard   1.239101
# 16                   Rice   3.786947
# 17                Sesamum   0.381257
# 18              Sugarcane  67.203737
# 19              Sunflower   1.821488
# 20                   Urad   0.599368
# 21                  Wheat   4.538871
# 22         other oilseeds   1.390000

# %%
df26=pd.read_csv("statwise seaparated csv files after dropping nulls/rajasthan_cropsallseason.csv")
df26=df26.groupby(["Crop"])["Yield"].mean().reset_index()
df26
# Out:
#                      Crop      Yield
# 0               Arhar/Tur   0.800271
# 1                   Bajra   0.916305
# 2                  Banana  10.431624
# 3                  Barley   2.537446
# 4             Castor seed   0.934075
# 5               Coriander   1.029134
# 6            Cotton(lint)   2.321075
# 7            Dry chillies   1.249215
# 8                  Garlic   3.130938
# 9                  Ginger   2.776357
# 10                   Gram   0.943736
# 11              Groundnut   1.420826
# 12              Guar seed   0.626932
# 13                  Jowar   0.628060
# 14                Linseed   0.906364
# 15                  Maize   1.420106
# 16                 Masoor   0.993357
# 17                  Mesta   0.516680
# 18      Moong(Green Gram)   0.355607
# 19                   Moth   0.266707
# 20         Oilseeds total   0.000000
# 21                  Onion   6.024727
# 22    Other Kharif pulses   0.435167
# 23      Other Rabi pulses   1.931537
# ...

# %%
df27=pd.read_csv("statwise seaparated csv files after dropping nulls/sikkim_cropsallseason.csv")
df27=df27.groupby(["Crop"])["Yield"].mean().reset_index()
df27
# Out:
#                    Crop     Yield
# 0                Barley  1.066512
# 1                 Maize  1.899946
# 2        Oilseeds total  0.595077
# 3         Other Cereals  0.880148
# 4   Other Kharif pulses  1.078267
# 5     Other Rabi pulses  1.087083
# 6                Potato  4.776608
# 7     Rapeseed &Mustard  0.875550
# 8                  Rice  2.050141
# 9         Small millets  1.031094
# 10             Soyabean  1.020799
# 11                 Urad  1.009238
# 12                Wheat  1.175629
# 13       other oilseeds  0.554545

# %%
df28=pd.read_csv("statwise seaparated csv files after dropping nulls/tamil_Nadu_cropsallseason.csv")
df28=df28.groupby(["Crop"])["Yield"].mean().reset_index()
df28
# Out:
#                    Crop         Yield
# 0              Arecanut      1.770466
# 1             Arhar/Tur      0.798832
# 2                 Bajra      2.080815
# 3                Banana     40.847762
# 4          Black pepper      0.214335
# 5              Cardamom      0.129480
# 6             Cashewnut     21.269248
# 7           Castor seed      0.393894
# 8               Coconut  11300.136910
# 9             Coriander      0.407140
# 10         Cotton(lint)      2.107929
# 11        Cowpea(Lobia)      0.743077
# 12         Dry chillies      0.687269
# 13               Garlic      5.208323
# 14               Ginger     17.130435
# 15                 Gram      0.627944
# 16            Groundnut      2.430638
# 17            Guar seed     10.651665
# 18           Horse-gram      0.543248
# 19                Jowar      1.282202
# 20                Maize      5.279873
# 21               Masoor      1.136800
# 22                Mesta      4.530002
# 23    Moong(Green Gram)      0.522734
# ...

# %%
df29=pd.read_csv("statwise seaparated csv files after dropping nulls/telangana_cropsallseason.csv")
df29=df29.groupby(["Crop"])["Yield"].mean().reset_index()
df29
# Out:
#                    Crop         Yield
# 0             Arhar/Tur      0.812357
# 1                 Bajra      0.932931
# 2                Banana     55.005428
# 3             Cashewnut      0.367774
# 4           Castor seed      0.788769
# 5               Coconut  18679.500000
# 6             Coriander      0.777911
# 7          Cotton(lint)      2.592443
# 8         Cowpea(Lobia)      0.995042
# 9          Dry chillies      4.448774
# 10               Garlic      2.902927
# 11               Ginger      6.816648
# 12                 Gram      1.426185
# 13            Groundnut      2.137744
# 14           Horse-gram      0.595070
# 15                Jowar      1.211311
# 16              Linseed      0.451646
# 17                Maize      5.086439
# 18               Masoor      0.416601
# 19                Mesta      8.343417
# 20    Moong(Green Gram)      0.759347
# 21           Niger seed      0.350000
# 22       Oilseeds total      2.188285
# 23                Onion     25.341501
# ...

# %%
df30=pd.read_csv("statwise seaparated csv files after dropping nulls/tripura_cropsallseason.csv")
df30=df30.groupby(["Crop"])["Yield"].mean().reset_index()
df30
# Out:
#                      Crop      Yield
# 0               Arhar/Tur   0.730371
# 1            Cotton(lint)   1.367121
# 2           Cowpea(Lobia)   0.735420
# 3                    Gram   0.744691
# 4               Groundnut   1.188200
# 5                   Jowar   0.806781
# 6                    Jute   8.492750
# 7                 Khesari   0.670838
# 8                 Linseed   0.696828
# 9                   Maize   1.351421
# 10                 Masoor   0.684168
# 11                  Mesta   8.153099
# 12      Moong(Green Gram)   0.566553
# 13         Oilseeds total   0.696510
# 14    Other Kharif pulses   0.754641
# 15      Other Rabi pulses   0.825402
# 16  Peas & beans (Pulses)   0.799017
# 17                 Potato  17.733842
# 18      Rapeseed &Mustard   0.797882
# 19                   Rice   2.503256
# 20                Sesamum   0.571748
# 21          Small millets   0.809895
# 22               Soyabean   0.782618
# 23              Sugarcane  51.614874
# ...

# %%
df31=pd.read_csv("statwise seaparated csv files after dropping nulls/uttar_Pradesh_cropsallseason.csv")
df31=df31.groupby(["Crop"])["Yield"].mean().reset_index()
df31
# Out:
#                      Crop      Yield
# 0               Arhar/Tur   0.929636
# 1                   Bajra   1.415880
# 2                  Banana  44.012354
# 3                  Barley   2.305156
# 4             Castor seed   0.729532
# 5               Coriander   0.570320
# 6            Cotton(lint)   0.555877
# 7            Dry chillies   0.893339
# 8                  Garlic   5.484354
# 9                  Ginger   3.437600
# 10                   Gram   0.985320
# 11              Groundnut   0.882217
# 12              Guar seed   0.803983
# 13                  Jowar   1.005479
# 14                   Jute   0.811781
# 15                Linseed   0.457489
# 16                  Maize   1.774404
# 17                 Masoor   0.837272
# 18      Moong(Green Gram)   0.508621
# 19                   Moth   0.450325
# 20         Oilseeds total   0.627343
# 21                  Onion  14.218432
# 22    Other Kharif pulses   0.543089
# 23      Other Rabi pulses   1.039878
# ...

# %%
df32=pd.read_csv("statwise seaparated csv files after dropping nulls/uttarakhand_cropsallseason.csv")
df32=df32.groupby(["Crop"])["Yield"].mean().reset_index()
df32
# Out:
#                      Crop      Yield
# 0               Arhar/Tur   0.717306
# 1                   Bajra   1.087787
# 2                  Barley   1.264821
# 3            Dry chillies   0.303062
# 4                  Garlic   1.914494
# 5                  Ginger   9.658504
# 6                    Gram   0.683331
# 7               Groundnut   1.085799
# 8              Horse-gram   0.766859
# 9                   Jowar   0.733333
# 10                Linseed   0.410974
# 11                  Maize   1.505862
# 12                 Masoor   0.647449
# 13      Moong(Green Gram)   0.586877
# 14                   Moth   0.454495
# 15         Oilseeds total   0.720695
# 16                  Onion   8.669762
# 17          Other Cereals   0.847078
# 18    Other Kharif pulses   0.857934
# 19      Other Rabi pulses   0.640758
# 20    Other Summer Pulses   0.625000
# 21  Peas & beans (Pulses)   0.685693
# 22                 Potato  12.199551
# 23                   Ragi   1.432464
# ...

# %%
df33=pd.read_csv("statwise seaparated csv files after dropping nulls/west_Bengalcropsallseason.csv")
df33=df33.groupby(["Crop"])["Yield"].mean().reset_index()
df33
# Out:
#                      Crop         Yield
# 0                Arecanut      2.013950
# 1               Arhar/Tur      1.082532
# 2                   Bajra      0.567628
# 3                  Barley      1.319256
# 4                Cardamom      0.482573
# 5             Castor seed      0.719730
# 6                 Coconut  12490.344135
# 7            Cotton(lint)      2.652120
# 8            Dry chillies      1.030352
# 9                  Garlic     10.537881
# 10                 Ginger      1.666708
# 11                   Gram      0.981734
# 12              Groundnut      1.575359
# 13             Horse-gram      0.530310
# 14                  Jowar      0.629689
# 15                   Jute     15.514682
# 16                Khesari      0.943617
# 17                Linseed      0.336762
# 18                  Maize      3.016155
# 19                 Masoor      0.717955
# 20                  Mesta      9.811239
# 21      Moong(Green Gram)      0.662495
# ...
